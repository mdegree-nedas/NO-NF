# %% [markdown]
# # Executions

# %% [markdown]
# Questo notebook rappresenta l'hub centrale per l'esecuzione dei test.
#
# I risultati dei vari test si trovano all'interno dei file /results/*.txt generati ad ogni esecuzione.

# %% [markdown]
# ## Variazioni T con istanze variabili generate randomicamente

# %%
# Automatic execution: change __name__ enables automatic execution mode in notebooks
__name__ = '__autoexec__'

# %%
# notebooks test parameters (i parametri saranno utilizzati dai notebooks)

# le T da testare
Ts = [5,10,15,20,30,50,70,100,150,200]

# lower bound e upper bound random
l_b = 10
u_b = 20

# %%
## run test on notebooks

for i in Ts:
    T = i
    
    # %run -n CSILSP-AGG.ipynb
    
    input()
# Out:
# Optimize a model with 15 rows, 15 columns and 31 nonzeros
# Variable types: 10 continuous, 5 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+01]
#   Objective range  [1e+01, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 1e+01]
# Presolve removed 15 rows and 15 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds
# Thread count was 1 (of 4 available processors)
#
# Solution count 1: 465
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.650000000000e+02, best bound 4.650000000000e+02, gap 0.0000%
#
# Optimize a model with 30 rows, 30 columns and 66 nonzeros
# Variable types: 20 continuous, 10 integer (10 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+01, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 2e+01]
# Presolve removed 18 rows and 12 columns
# ...

# %%
for i in Ts:
    T = i
    
    # %run -n CSILSP-FAL.ipynb
    
    input()
# Out:
# Optimize a model with 25 rows, 30 columns and 60 nonzeros
# Variable types: 25 continuous, 5 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+01, 7e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 3e+01]
# Presolve removed 13 rows and 14 columns
# Presolve time: 0.00s
# Presolved: 12 rows, 16 columns, 36 nonzeros
# Variable types: 13 continuous, 3 integer (3 binary)
#
# Root relaxation: objective 1.338000e+03, 3 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1338.0000000 1338.00000  0.00%     -    0s
#
# Explored 0 nodes (3 simplex iterations) in 0.04 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 1338
#
# Optimal solution found (tolerance 1.00e-04)
# ...

# %%
for i in Ts:
    T = i
    
    # %run -n CSILSP-NCS.ipynb
    
    input()
# Out:
# Optimize a model with 20 rows, 15 columns and 46 nonzeros
# Variable types: 10 continuous, 5 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+01, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 16 rows and 9 columns
# Presolve time: 0.00s
# Presolved: 4 rows, 6 columns, 9 nonzeros
# Variable types: 4 continuous, 2 integer (2 binary)
#
# Root relaxation: objective 6.830000e+02, 4 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  683.00000    0    1          -  683.00000      -     -    0s
# H    0     0                     698.0000000  683.00000  2.15%     -    0s
#      0     0     cutoff    0       698.00000  698.00000  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.04 seconds
# ...

# %%
for i in Ts:
    T = i
    
    # %run -n CSILSP-CS.ipynb
    
    input()
# Out:
# Optimize a model with 35 rows, 15 columns and 81 nonzeros
# Variable types: 10 continuous, 5 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+01, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 2e+02]
# Presolve removed 28 rows and 7 columns
# Presolve time: 0.00s
# Presolved: 7 rows, 8 columns, 20 nonzeros
# Variable types: 5 continuous, 3 integer (3 binary)
#
# Root relaxation: objective 2.827109e+03, 5 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2827.10870    0    1          - 2827.10870      -     -    0s
# H    0     0                    2832.0000000 2827.10870  0.17%     -    0s
#      0     0     cutoff    0      2832.00000 2832.00000  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.04 seconds
# ...

# %%
for i in Ts:
    T = i
    
    # %run -n CSILSP-NCS-CS-FAL.ipynb
    
    input()
# Out:
# Optimize a model with 40 rows, 30 columns and 94 nonzeros
# Variable types: 25 continuous, 5 integer (5 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+01, 7e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 7e+01]
# Presolve removed 26 rows and 16 columns
# Presolve time: 0.00s
# Presolved: 14 rows, 14 columns, 42 nonzeros
# Variable types: 12 continuous, 2 integer (2 binary)
#
# Root relaxation: objective 5.329353e+03, 10 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5329.35294    0    1          - 5329.35294      -     -    0s
# H    0     0                    5339.0000000 5329.35294  0.18%     -    0s
#      0     0     cutoff    0      5339.00000 5339.00000  0.00%     -    0s
#
# Explored 1 nodes (10 simplex iterations) in 0.04 seconds
# ...

# %% [markdown]
# ## Variazioni di T con istanza fissa generata randomicamente

# %%
import CSILSPGenerator as gen

# %%
# Automatic execution: change __name__ enables automatic execution mode in notebooks with fixed istance
__name__ = '__autoexec_with_fixed_istance__'

# %%
# tests parameters (T=10,50,100,200)
T = 200

l_b = 10
u_b = 20

# %%
# classical CSILSP istance

instance = gen.Generator(T)
instance.generate(a=l_b,b=u_b)

# %%
## run test on notebooks with fixed T

# %run -n CSILSP-AGG.ipynb
# Out:
# Optimize a model with 600 rows, 600 columns and 1396 nonzeros
# Variable types: 400 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [1e+01, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 2e+01]
# Found heuristic solution: objective 45975.000000
# Presolve removed 228 rows and 31 columns
# Presolve time: 0.01s
# Presolved: 372 rows, 569 columns, 940 nonzeros
# Variable types: 372 continuous, 197 integer (197 binary)
#
# Root relaxation: objective 4.504647e+04, 413 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 45046.4678    0  175 45975.0000 45046.4678  2.02%     -    0s
#      0     0     cutoff    0      45975.0000 45975.0000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 110
#   Implied bound: 54
#   MIR: 4
#   Flow cover: 47
#
# ...

# %%
# %run -n CSILSP-FAL.ipynb
# Out:
# Optimize a model with 20500 rows, 40200 columns and 80400 nonzeros
# Variable types: 40000 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+01, 3e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 4e+01]
# Presolve removed 4417 rows and 19904 columns
# Presolve time: 0.15s
# Presolved: 16083 rows, 20296 columns, 71764 nonzeros
# Variable types: 20098 continuous, 198 integer (198 binary)
#
# Root relaxation: objective 4.658700e+04, 254 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    46587.000000 46587.0000  0.00%     -    0s
#
# Explored 0 nodes (254 simplex iterations) in 0.27 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 46587
#
# Optimal solution found (tolerance 1.00e-04)
# ...

# %%
# CSILSP-CS istance

instance = gen.GeneratorTW_CS(T)
instance.generate(a=l_b,b=u_b,dw_a=l_b,dw_b=u_b)

# %%
# %run -n CSILSP-CS.ipynb
# Out:
# Optimize a model with 20900 rows, 600 columns and 1374896 nonzeros
# Variable types: 400 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+01, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 3e+05]
# Presolve removed 509 rows and 72 columns
# Presolve time: 3.75s
# Presolved: 20391 rows, 528 columns, 1373405 nonzeros
# Variable types: 330 continuous, 198 integer (198 binary)
#
# Root relaxation: objective 7.415185e+07, 431 iterations, 0.89 seconds
# Total elapsed time = 5.35s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7.4152e+07    0  130          - 7.4152e+07      -     -    5s
# H    0     0                    7.415374e+07 7.4152e+07  0.00%     -    6s
#
# Explored 1 nodes (431 simplex iterations) in 6.42 seconds
# ...

# %%
# %run -n CSILSP-NCS-CS-FAL.ipynb
# Out:
# Optimize a model with 40600 rows, 40200 columns and 1433799 nonzeros
# Variable types: 40000 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [1e+01, 3e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 7e+04]
# Found heuristic solution: objective 1.179194e+08
# Presolve removed 2878 rows and 19903 columns
# Presolve time: 3.04s
# Presolved: 37722 rows, 20297 columns, 1389516 nonzeros
# Variable types: 20097 continuous, 200 integer (200 binary)
#
# Root relaxation: objective 7.443212e+07, 2788 iterations, 0.38 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7.443212e+07 7.4432e+07  0.00%     -    3s
#
# Explored 0 nodes (2788 simplex iterations) in 3.69 seconds
# Thread count was 4 (of 4 available processors)
#
# ...

# %%
# CSILSP-NCS istance

instance = gen.GeneratorTW_NCS(T)
instance.generate(a=l_b,b=u_b,dw_a=l_b,dw_b=u_b)

# %%
# %run -n CSILSP-NCS.ipynb
# Out:
# Optimize a model with 800 rows, 600 columns and 21496 nonzeros
# Variable types: 400 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+03]
#   Objective range  [1e+01, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 6e+03]
# Found heuristic solution: objective 46097.000000
# Presolve removed 212 rows and 10 columns
# Presolve time: 0.03s
# Presolved: 588 rows, 590 columns, 20677 nonzeros
# Variable types: 393 continuous, 197 integer (197 binary)
#
# Root relaxation: objective 4.316212e+04, 435 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 43162.1161    0  196 46097.0000 43162.1161  6.37%     -    0s
# *    0     0               0    46082.000000 46082.0000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 195
#   Implied bound: 1
#   MIR: 6
#   Flow cover: 3
#
# ...
