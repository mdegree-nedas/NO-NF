# %% [markdown]
# # Result Analysis

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %% [markdown]
# I test sono stati eseguiti su un computer portatile Asus con processore Intel® Core™ i7 3537U - 2.00 GHz, con 8 GB di RAM DDR3.
#
# Sono stati utilizzati i file .txt nella cartella /results del progetto per l'analisi dei risultati.

# %% [markdown]
# ## Analisi formulazioni con istanze sempre diverse generate randomicamente

# %% [markdown]
# ### AGG

# %%
T_Times_1 = { 5:0.021986  , 10:0.057392  , 15:0.035522  , 20:0.033978 ,  30:0.035236  , 
             50:0.046242  , 70:0.055979  , 100:0.053532  , 150:0.061178  , 200:0.075846  }

print("max execution time:",max(T_Times_1.values()))

plt.plot(T_Times_1.keys(), T_Times_1.values(),linewidth=2,marker='o')
plt.ylabel('Esecuzione (sec)')
plt.xlabel('T')
plt.show()
# Out:
# max execution time: 0.075846

# %%
T_Times_2 = { 5:0.022972   , 10:0.041649   , 15:0.035643  , 20:0.050657 ,  30:0.046021  , 50:0.041613  , 
             70:0.048347  , 100:0.068447  , 150:0.074812  , 200:0.094166  }

print("max execution time:",max(T_Times_2.values()))

plt.plot(T_Times_2.keys(), T_Times_2.values(),linewidth=2,marker='o')
plt.ylabel('Esecuzione (sec)')
plt.xlabel('T')
plt.show()
# Out:
# max execution time: 0.094166

# %%
T_Times_3 = { 5:0.026127   , 10:0.038975   , 15:0.03994   , 20:0.028873 , 
             30:0.041937   , 50:0.065571   , 70:0.062212   , 100:0.083616   , 
             150:0.083876  , 200:0.094194   }

print("max execution time:",max(T_Times_3.values()))

plt.plot(T_Times_3.keys(), T_Times_3.values(),linewidth=2,marker='o')
plt.ylabel('Esecuzione (sec)')
plt.xlabel('T')
plt.show()
# Out:
# max execution time: 0.094194

# %%
T_Times_4 = { 5:0.019985   , 10:0.071545   , 15:0.031979   , 
             20:0.04072 ,  30:0.038963   , 50:0.042953   , 70:0.049053   , 
             100:0.071074   , 150:0.090019   , 200:0.084261   }

print("max execution time:",max(T_Times_4.values()))

plt.plot(T_Times_4.keys(), T_Times_4.values(),linewidth=2,marker='o')
plt.ylabel('Esecuzione (sec)')
plt.xlabel('T')
plt.show()
# Out:
# max execution time: 0.090019

# %%
T_Times_5 = { 5:0.019016   , 10:0.04661   , 15:0.036974   , 20:0.03298   ,
             30:0.043833   , 50:0.056725   , 70:0.045786  , 100:0.070782 , 
             150:0.087769   , 200:0.085239  }

print("max execution time:",max(T_Times_5.values()))

plt.plot(T_Times_5.keys(), T_Times_5.values(),linewidth=2,marker='o')
plt.ylabel('Esecuzione (sec)')
plt.xlabel('T')
plt.show()
# Out:
# max execution time: 0.087769

# %% [markdown]
# ### CS

# %%
T_Times_1 = { 5:0.034653   , 10:0.053551    , 15:0.058306   , 
             20:0.059393 ,  30:0.07159   , 50:0.17758   , 70:0.35074   , 
             100:1.0816   , 150:2.4817   , 200:7.2676   }

print("max execution time:",max(T_Times_1.values()))

plt.plot(T_Times_1.keys(), T_Times_1.values(),linewidth=2,marker='o')
plt.ylabel('Esecuzione (sec)')
plt.xlabel('T')
plt.show()
# Out:
# max execution time: 7.2676

# %%
T_Times_2 = { 5:0.046535    , 10:0.049973    , 15:0.044575   , 20:0.040026   ,
             30:0.051531   , 50:0.16077   , 70:0.2645   , 100:1.5841   , 
             150:2.9959   , 200:7.8312   }

print("max execution time:",max(T_Times_2.values()))

plt.plot(T_Times_2.keys(), T_Times_2.values(),linewidth=2,marker='o')
plt.ylabel('Esecuzione (sec)')
plt.xlabel('T')
plt.show()
# Out:
# max execution time: 7.8312

# %%
T_Times_3 = { 5:0.044729    , 10:0.04019   , 15:0.04565  , 
             20:0.044706 ,  30:0.076916     , 50:0.16156    , 70:0.3031   , 
             100:1.1449   , 150:3.1428   , 200:6.671    }

print("max execution time:",max(T_Times_3.values()))

plt.plot(T_Times_3.keys(), T_Times_3.values(),linewidth=2,marker='o')
plt.ylabel('Esecuzione (sec)')
plt.xlabel('T')
plt.show()
# Out:
# max execution time: 6.671

# %%
T_Times_4 = { 5:0.048433     , 10:0.061281     , 15:0.054293   , 20:0.056566   ,
             30:0.077948   , 50:0.20583   , 70:0.28882    , 100:1.2148   , 
             150:3.3582  , 200:14.996   }

print("max execution time:",max(T_Times_4.values()))

plt.plot(T_Times_4.keys(), T_Times_4.values(),linewidth=2,marker='o')
plt.ylabel('Esecuzione (sec)')
plt.xlabel('T')
plt.show()
# Out:
# max execution time: 14.996

# %%
T_Times_5 = { 5:0.051962   , 10:0.046053    , 15:0.060953   , 20:0.046175   ,
             30:0.082853   , 50:0.14819  , 70:0.28174   , 100:1.5274 , 
             150:3.3345   , 200:6.4536   }

print("max execution time:",max(T_Times_5.values()))

plt.plot(T_Times_5.keys(), T_Times_5.values(),linewidth=2,marker='o')
plt.ylabel('Esecuzione (sec)')
plt.xlabel('T')
plt.show()
# Out:
# max execution time: 6.4536

# %% [markdown]
# ### FAL

# %%
T_Times_1 = { 5:0.050404   , 10:0.044022  , 15:0.039721  , 20:0.04286  ,
             30:0.051838  , 50:0.051804  , 70:0.10333   , 100:0.10373   , 
             150:0.16918  , 200:0.29238 }

print("max execution time:",max(T_Times_1.values()))

plt.plot(T_Times_1.keys(), T_Times_1.values(),linewidth=2,marker='o')
plt.ylabel('Esecuzione (sec)')
plt.xlabel('T')
plt.show()
# Out:
# max execution time: 0.29238

# %%
T_Times_2 = { 5:0.043728    , 10:0.036282   , 15:0.0352   , 20:0.036976   ,
             30:0.058435   , 50:0.05221  , 70:0.0825  , 100:0.11659   , 
             150:0.17019   , 200:0.28807   }

print("max execution time:",max(T_Times_2.values()))

plt.plot(T_Times_2.keys(), T_Times_2.values(),linewidth=2,marker='o')
plt.ylabel('Esecuzione (sec)')
plt.xlabel('T')
plt.show()
# Out:
# max execution time: 0.28807

# %%
T_Times_3 = { 5:0.038704    , 10:0.041985    , 15:0.045834   , 20:0.048969   ,
             30:0.045856  , 50:0.050556   , 70:0.068258    , 100:0.10549   , 
             150:0.17338   , 200:0.43368    }

print("max execution time:",max(T_Times_3.values()))

plt.plot(T_Times_3.keys(), T_Times_3.values(),linewidth=2,marker='o')
plt.ylabel('Esecuzione (sec)')
plt.xlabel('T')
plt.show()
# Out:
# max execution time: 0.43368

# %%
T_Times_4 = { 5:0.04645   , 10:0.042721   , 15:0.035976  , 
             20:0.05068  ,  30:0.049732   , 50:0.053215   , 70:0.07843    , 
             100:0.16728   , 150:0.15789   , 200:0.28957   }

print("max execution time:",max(T_Times_4.values()))

plt.plot(T_Times_4.keys(), T_Times_4.values(),linewidth=2,marker='o')
plt.ylabel('Esecuzione (sec)')
plt.xlabel('T')
plt.show()
# Out:
# max execution time: 0.28957

# %%
T_Times_5 = { 5:0.047159    , 10:0.063925    , 15:0.047392    , 20:0.051207    ,
             30:0.062223    , 50:0.054991   , 70:0.083517   , 100:0.1058 , 
             150:0.17026    , 200:0.28051   }

print("max execution time:",max(T_Times_5.values()))

plt.plot(T_Times_5.keys(), T_Times_5.values(),linewidth=2,marker='o')
plt.ylabel('Esecuzione (sec)')
plt.xlabel('T')
plt.show()
# Out:
# max execution time: 0.28051

# %% [markdown]
# ### NCS

# %%
T_Times_1 = { 5:0.048092   , 10:0.042603   , 15:0.050076   , 20:0.046217  ,
             30:0.058352  , 50:0.071915   , 70:0.075417   , 100:0.15496   , 
             150:0.33894   , 200:0.71054   }

print("max execution time:",max(T_Times_1.values()))

plt.plot(T_Times_1.keys(), T_Times_1.values(),linewidth=2,marker='o')
plt.ylabel('Esecuzione (sec)')
plt.xlabel('T')
plt.show()
# Out:
# max execution time: 0.71054

# %%
T_Times_2 = { 5:0.043222    , 10:0.044762   , 15:0.047255   , 20:0.042789  ,
             30:0.055353   , 50:0.079109   , 70:0.091639   , 100:0.15287  , 
             150:0.34044 , 200:0.61428 }

print("max execution time:",max(T_Times_2.values()))

plt.plot(T_Times_2.keys(), T_Times_2.values(),linewidth=2,marker='o')
plt.ylabel('Esecuzione (sec)')
plt.xlabel('T')
plt.show()
# Out:
# max execution time: 0.61428

# %%
T_Times_3 = { 5:0.047752   , 10:0.02898   , 15:0.047686   , 20:0.036274  ,
             30:0.051258   , 50:0.072212   , 70:0.10023   , 100:0.14057   , 
             150:0.33954  , 200:0.17736   }

print("max execution time:",max(T_Times_3.values()))

plt.plot(T_Times_3.keys(), T_Times_3.values(),linewidth=2,marker='o')
plt.ylabel('Esecuzione (sec)')
plt.xlabel('T')
plt.show()
# Out:
# max execution time: 0.33954

# %%
T_Times_4 = { 5:0.036394   , 10:0.046783   , 15:0.037989    , 
             20:0.034405  , 30:0.062529   , 50:0.071033   , 70:0.092108   , 
             100:0.15471    , 150:0.33626   , 200:0.62541   }

print("max execution time:",max(T_Times_4.values()))

plt.plot(T_Times_4.keys(), T_Times_4.values(),linewidth=2,marker='o')
plt.ylabel('Esecuzione (sec)')
plt.xlabel('T')
plt.show()
# Out:
# max execution time: 0.62541

# %%
T_Times_5 = { 5:0.054888   , 10:0.041948    , 15:0.049419   , 20:0.040071  ,
             30:0.058046   , 50:0.060284   , 70:0.087234  , 100:0.15306  , 
             150:0.33101   , 200:0.35063   }

print("max execution time:",max(T_Times_5.values()))

plt.plot(T_Times_5.keys(), T_Times_5.values(),linewidth=2,marker='o')
plt.ylabel('Esecuzione (sec)')
plt.xlabel('T')
plt.show()
# Out:
# max execution time: 0.35063

# %% [markdown]
# ### NCS-CS-FAL

# %%
T_Times_1 = { 5:0.040596  , 10:0.043974  , 15:0.050404  , 20:0.043022  ,
             30:0.053701  , 50:0.10413   , 70:0.31481   , 100:1.682   , 
             150:5.9999   , 200:9.7737  }

print("max execution time:",max(T_Times_1.values()))

plt.plot(T_Times_1.keys(), T_Times_1.values(),linewidth=2,marker='o')
plt.ylabel('Esecuzione (sec)')
plt.xlabel('T')
plt.show()
# Out:
# max execution time: 9.7737

# %%
T_Times_2 = { 5:0.051474   , 10:0.035336  , 15:0.047695   , 
             20:0.043568 , 30:0.06287   , 50:0.14702   , 70:0.22186   , 
             100:0.64143  , 150:1.9881   , 200:11.326   }

print("max execution time:",max(T_Times_2.values()))

plt.plot(T_Times_2.keys(), T_Times_2.values(),linewidth=2,marker='o')
plt.ylabel('Esecuzione (sec)')
plt.xlabel('T')
plt.show()
# Out:
# max execution time: 11.326

# %%
T_Times_3 = { 5:0.025986    , 10:0.048365    , 15:0.04587   , 20:0.046751  ,
             30:0.067312   , 50:0.11103  , 70:0.34858   , 100:1.6089    , 
             150:6.8564   , 200:14.839   }

print("max execution time:",max(T_Times_3.values()))

plt.plot(T_Times_3.keys(), T_Times_3.values(),linewidth=2,marker='o')
plt.ylabel('Esecuzione (sec)')
plt.xlabel('T')
plt.show()
# Out:
# max execution time: 14.839

# %%
T_Times_4 = { 5:0.04911   , 10:0.046253    , 15:0.038816    , 
             20:0.050962 ,  30:0.053844    , 50:0.10714   , 70:0.29014   , 
             100:0.64993    , 150:1.5853   , 200:7.6659    }

print("max execution time:",max(T_Times_4.values()))

plt.plot(T_Times_4.keys(), T_Times_4.values(),linewidth=2,marker='o')
plt.ylabel('Esecuzione (sec)')
plt.xlabel('T')
plt.show()
# Out:
# max execution time: 7.6659

# %%
T_Times_5 = { 5:0.0478   , 10:0.043358   , 15:0.054129   , 20:0.042158  ,
             30:0.079884  , 50:0.10686    , 70:0.21803   , 100:0.57273  , 
             150:6.2565   , 200:14.414  }

print("max execution time:",max(T_Times_5.values()))

plt.plot(T_Times_5.keys(), T_Times_5.values(),linewidth=2,marker='o')
plt.ylabel('Esecuzione (sec)')
plt.xlabel('T')
plt.show()
# Out:
# max execution time: 14.414

# %% [markdown]
# ## Analisi formulazioni con istanze fisse generate randomicamente
# ### (stessa istanza per le formulazioni dello stesso tipo)

# %%
T_10_1_group1 = { 'agg':0.030884   ,'fal':0.035976 }

T_10_1_group2 = { 'cs':0.053036 , 'ncs':0.027544   ,'ncs-cs-fal':0.02644 }


T_10_2_group1 = { 'agg':0.016104   , 'fal':0.038078 }

T_10_2_group2 = { 'cs':0.037451 , 'ncs':0.047089 ,'ncs-cs-fal':0.050274  }


T_10_3_group1 = { 'agg':0.03166 , 'fal':0.025984 }

T_10_3_group2 = {'cs':0.050264 ,'ncs':0.054489   ,'ncs-cs-fal':0.056435   }


plt.figure(figsize=(12,5))
plt.subplots_adjust(wspace=0.5)
plt.subplot(1,2,1)
plt.bar(T_10_1_group1.keys(),T_10_1_group1.values(),align='center', alpha=0.5)
plt.ylabel('Esecuzione (sec)')
plt.xlabel('Formulazioni')

plt.subplot(1,2,2)
plt.ylabel('Esecuzione (sec)')
plt.xlabel('Formulazioni')
plt.bar(T_10_1_group2.keys(),T_10_1_group2.values(),align='center', alpha=0.5)

plt.show()



plt.figure(figsize=(12,5))
plt.subplots_adjust(wspace=0.5)
plt.subplot(1,2,1)
plt.bar(T_10_2_group1.keys(),T_10_2_group1.values(),align='center', alpha=0.5)
plt.ylabel('Esecuzione (sec)')
plt.xlabel('Formulazioni')

plt.subplot(1,2,2)
plt.ylabel('Esecuzione (sec)')
plt.xlabel('Formulazioni')
plt.bar(T_10_2_group2.keys(),T_10_2_group2.values(),align='center', alpha=0.5)

plt.show()



plt.figure(figsize=(12,5))
plt.subplots_adjust(wspace=0.5)
plt.subplot(1,2,1)
plt.bar(T_10_3_group1.keys(),T_10_3_group1.values(),align='center', alpha=0.5)
plt.ylabel('Esecuzione (sec)')
plt.xlabel('Formulazioni')

plt.subplot(1,2,2)
plt.ylabel('Esecuzione (sec)')
plt.xlabel('Formulazioni')
plt.bar(T_10_3_group2.keys(),T_10_3_group2.values(),align='center', alpha=0.5)

plt.show()

# %%
T_50_1_group1 = { 'agg':0.044281,'fal':0.050486 }

T_50_1_group2 = { 'cs':0.11457  ,
        'ncs':0.078394  ,'ncs-cs-fal':0.12175   }


T_50_2_group1 = { 'agg':0.044632   ,'fal':0.049181 }

T_50_2_group2 = {'cs':0.13352  ,
        'ncs':0.081888   ,'ncs-cs-fal':0.11555   }


T_50_3_group1 = { 'agg':0.049337,'fal':0.079916 }

T_50_3_group2 = { 'cs':0.12608 , 'ncs':0.071733   ,'ncs-cs-fal':0.10023 }



plt.figure(figsize=(12,5))
plt.subplots_adjust(wspace=0.5)
plt.subplot(1,2,1)
plt.bar(T_50_1_group1.keys(),T_50_1_group1.values(),align='center', alpha=0.5)
plt.ylabel('Esecuzione (sec)')
plt.xlabel('Formulazioni')

plt.subplot(1,2,2)
plt.ylabel('Esecuzione (sec)')
plt.xlabel('Formulazioni')
plt.bar(T_50_1_group2.keys(),T_50_1_group2.values(),align='center', alpha=0.5)

plt.show()



plt.figure(figsize=(12,5))
plt.subplots_adjust(wspace=0.5)
plt.subplot(1,2,1)
plt.bar(T_50_2_group1.keys(),T_50_2_group1.values(),align='center', alpha=0.5)
plt.ylabel('Esecuzione (sec)')
plt.xlabel('Formulazioni')

plt.subplot(1,2,2)
plt.ylabel('Esecuzione (sec)')
plt.xlabel('Formulazioni')
plt.bar(T_50_2_group2.keys(),T_50_2_group2.values(),align='center', alpha=0.5)

plt.show()



plt.figure(figsize=(12,5))
plt.subplots_adjust(wspace=0.5)
plt.subplot(1,2,1)
plt.bar(T_50_3_group1.keys(),T_50_3_group1.values(),align='center', alpha=0.5)
plt.ylabel('Esecuzione (sec)')
plt.xlabel('Formulazioni')

plt.subplot(1,2,2)
plt.ylabel('Esecuzione (sec)')
plt.xlabel('Formulazioni')
plt.bar(T_50_3_group2.keys(),T_50_3_group2.values(),align='center', alpha=0.5)

plt.show()

# %%
T_100_1_group1 = { 'agg':0.067287  ,'fal':0.097462   }

T_100_1_group2 = { 'cs':0.8289  ,
        'ncs':0.14201   ,'ncs-cs-fal':0.58338   }


T_100_2_group1 = { 'agg':0.049376    ,'fal':0.097546  }

T_100_2_group2 = {'cs':0.83871,
        'ncs':0.086121   ,'ncs-cs-fal':0.66066   }


T_100_3_group1 = { 'agg':0.077915 , 'fal':0.14173    }

T_100_3_group2 = {'cs':0.73507  ,
        'ncs':0.1596   ,'ncs-cs-fal':0.58303    }



plt.figure(figsize=(12,5))
plt.subplots_adjust(wspace=0.5)
plt.subplot(1,2,1)
plt.bar(T_100_1_group1.keys(),T_100_1_group1.values(),align='center', alpha=0.5)
plt.ylabel('Esecuzione (sec)')
plt.xlabel('Formulazioni')

plt.subplot(1,2,2)
plt.ylabel('Esecuzione (sec)')
plt.xlabel('Formulazioni')
plt.bar(T_100_1_group2.keys(),T_100_1_group2.values(),align='center', alpha=0.5)

plt.show()



plt.figure(figsize=(12,5))
plt.subplots_adjust(wspace=0.5)
plt.subplot(1,2,1)
plt.bar(T_100_2_group1.keys(),T_100_2_group1.values(),align='center', alpha=0.5)
plt.ylabel('Esecuzione (sec)')
plt.xlabel('Formulazioni')

plt.subplot(1,2,2)
plt.ylabel('Esecuzione (sec)')
plt.xlabel('Formulazioni')
plt.bar(T_100_2_group2.keys(),T_100_2_group2.values(),align='center', alpha=0.5)

plt.show()



plt.figure(figsize=(12,5))
plt.subplots_adjust(wspace=0.5)
plt.subplot(1,2,1)
plt.bar(T_100_3_group1.keys(),T_100_3_group1.values(),align='center', alpha=0.5)
plt.ylabel('Esecuzione (sec)')
plt.xlabel('Formulazioni')

plt.subplot(1,2,2)
plt.ylabel('Esecuzione (sec)')
plt.xlabel('Formulazioni')
plt.bar(T_100_3_group2.keys(),T_100_3_group2.values(),align='center', alpha=0.5)

plt.show()

# %%
T_200_1_group1 = { 'agg':0.081146  ,'fal':0.28814   }

T_200_1_group2 = {'cs':6.0911  ,
        'ncs':0.61283   ,'ncs-cs-fal':3.6857   }


T_200_2_group1 = { 'agg':0.089451   ,'fal':0.3481  }

T_200_2_group2 = { 'cs':10.423 ,
        'ncs':0.63705   ,'ncs-cs-fal':13.765   }


T_200_3_group1 = { 'agg':0.082258   ,'fal':0.2823 }

T_200_3_group2 = { 'cs':6.4345   ,
        'ncs':0.62127   ,'ncs-cs-fal':3.7039   }



plt.figure(figsize=(12,5))
plt.subplots_adjust(wspace=0.5)
plt.subplot(1,2,1)
plt.bar(T_200_1_group1.keys(),T_200_1_group1.values(),align='center', alpha=0.5)
plt.ylabel('Esecuzione (sec)')
plt.xlabel('Formulazioni')

plt.subplot(1,2,2)
plt.ylabel('Esecuzione (sec)')
plt.xlabel('Formulazioni')
plt.bar(T_200_1_group2.keys(),T_200_1_group2.values(),align='center', alpha=0.5)

plt.show()



plt.figure(figsize=(12,5))
plt.subplots_adjust(wspace=0.5)
plt.subplot(1,2,1)
plt.bar(T_200_2_group1.keys(),T_200_2_group1.values(),align='center', alpha=0.5)
plt.ylabel('Esecuzione (sec)')
plt.xlabel('Formulazioni')

plt.subplot(1,2,2)
plt.ylabel('Esecuzione (sec)')
plt.xlabel('Formulazioni')
plt.bar(T_200_2_group2.keys(),T_200_2_group2.values(),align='center', alpha=0.5)

plt.show()



plt.figure(figsize=(12,5))
plt.subplots_adjust(wspace=0.5)
plt.subplot(1,2,1)
plt.bar(T_200_3_group1.keys(),T_200_3_group1.values(),align='center', alpha=0.5)
plt.ylabel('Esecuzione (sec)')
plt.xlabel('Formulazioni')

plt.subplot(1,2,2)
plt.ylabel('Esecuzione (sec)')
plt.xlabel('Formulazioni')
plt.bar(T_200_3_group2.keys(),T_200_3_group2.values(),align='center', alpha=0.5)

plt.show()

# %% [markdown]
# ## Comparazione esecuzioni per istanze fisse generate randomicamente

# %%
data_1_group1 = {'T_10':T_10_1_group1 ,'T_50':T_50_1_group1 ,'T_100':T_100_1_group1 ,'T_200':T_200_1_group1}

data_1_group2 = {'T_10':T_10_1_group2 ,'T_50':T_50_1_group2 ,'T_100':T_100_1_group2 ,'T_200':T_200_1_group2}


data_2_group1 = {'T_10':T_10_2_group1 ,'T_50':T_50_2_group1 ,'T_100':T_100_2_group1 ,'T_200':T_200_2_group1}

data_2_group2 = {'T_10':T_10_2_group2 ,'T_50':T_50_2_group2 ,'T_100':T_100_2_group2 ,'T_200':T_200_2_group2}


data_3_group1 = {'T_10':T_10_3_group1 ,'T_50':T_50_3_group1 ,'T_100':T_100_3_group1 ,'T_200':T_200_3_group1}

data_3_group2 = {'T_10':T_10_3_group2 ,'T_50':T_50_3_group2 ,'T_100':T_100_3_group2 ,'T_200':T_200_3_group2}

# %%
df_1_group1 = pd.DataFrame(data_1_group1).T
df_1_group2 = pd.DataFrame(data_1_group2).T

display(df_1_group1)
display(df_1_group2)
# Out:
#             agg       fal
# T_10   0.030884  0.035976
# T_50   0.044281  0.050486
# T_100  0.067287  0.097462
# T_200  0.081146  0.288140
#              cs       ncs  ncs-cs-fal
# T_10   0.053036  0.027544     0.02644
# T_50   0.114570  0.078394     0.12175
# T_100  0.828900  0.142010     0.58338
# T_200  6.091100  0.612830     3.68570

# %%
df_2_group1 = pd.DataFrame(data_2_group1).T
df_2_group2 = pd.DataFrame(data_2_group2).T

display(df_2_group1)
display(df_2_group2)
# Out:
#             agg       fal
# T_10   0.016104  0.038078
# T_50   0.044632  0.049181
# T_100  0.049376  0.097546
# T_200  0.089451  0.348100
#               cs       ncs  ncs-cs-fal
# T_10    0.037451  0.047089    0.050274
# T_50    0.133520  0.081888    0.115550
# T_100   0.838710  0.086121    0.660660
# T_200  10.423000  0.637050   13.765000

# %%
df_3_group1 = pd.DataFrame(data_3_group1).T
df_3_group2 = pd.DataFrame(data_3_group2).T

display(df_3_group1)
display(df_3_group2)
# Out:
#             agg       fal
# T_10   0.031660  0.025984
# T_50   0.049337  0.079916
# T_100  0.077915  0.141730
# T_200  0.082258  0.282300
#              cs       ncs  ncs-cs-fal
# T_10   0.050264  0.054489    0.056435
# T_50   0.126080  0.071733    0.100230
# T_100  0.735070  0.159600    0.583030
# T_200  6.434500  0.621270    3.703900

# %%
df_group1 = pd.concat([df_1_group1,df_2_group1,df_3_group1])

df_group2 = pd.concat([df_1_group2,df_2_group2,df_3_group2])


display(df_group1)
display(df_group2)
# Out:
#             agg       fal
# T_10   0.030884  0.035976
# T_50   0.044281  0.050486
# T_100  0.067287  0.097462
# T_200  0.081146  0.288140
# T_10   0.016104  0.038078
# T_50   0.044632  0.049181
# T_100  0.049376  0.097546
# T_200  0.089451  0.348100
# T_10   0.031660  0.025984
# T_50   0.049337  0.079916
# T_100  0.077915  0.141730
# T_200  0.082258  0.282300
#               cs       ncs  ncs-cs-fal
# T_10    0.053036  0.027544    0.026440
# T_50    0.114570  0.078394    0.121750
# T_100   0.828900  0.142010    0.583380
# T_200   6.091100  0.612830    3.685700
# T_10    0.037451  0.047089    0.050274
# T_50    0.133520  0.081888    0.115550
# T_100   0.838710  0.086121    0.660660
# T_200  10.423000  0.637050   13.765000
# T_10    0.050264  0.054489    0.056435
# T_50    0.126080  0.071733    0.100230
# T_100   0.735070  0.159600    0.583030
# T_200   6.434500  0.621270    3.703900

# %%
display(df_group1.describe())
display(df_group2.describe())
# Out:
#              agg        fal
# count  12.000000  12.000000
# mean    0.055361   0.127908
# std     0.023767   0.113394
# min     0.016104   0.025984
# 25%     0.041126   0.046405
# 50%     0.049356   0.088689
# 75%     0.078723   0.176872
# max     0.089451   0.348100
#               cs        ncs  ncs-cs-fal
# count  12.000000  12.000000   12.000000
# mean    2.155517   0.218335    1.954362
# std     3.482066   0.247226    3.955496
# min     0.037451   0.027544    0.026440
# 25%     0.099187   0.067422    0.089281
# 50%     0.434295   0.084005    0.352390
# 75%     2.151807   0.272907    1.416920
# max    10.423000   0.637050   13.765000

# %%
display(df_group1.loc['T_10'])
display(df_group2.loc['T_10'])
# Out:
#            agg       fal
# T_10  0.030884  0.035976
# T_10  0.016104  0.038078
# T_10  0.031660  0.025984
#             cs       ncs  ncs-cs-fal
# T_10  0.053036  0.027544    0.026440
# T_10  0.037451  0.047089    0.050274
# T_10  0.050264  0.054489    0.056435

# %%
display(df_group1.loc['T_10'].describe())
display(df_group2.loc['T_10'].describe())
# Out:
#             agg       fal
# count  3.000000  3.000000
# mean   0.026216  0.033346
# std    0.008766  0.006462
# min    0.016104  0.025984
# 25%    0.023494  0.030980
# 50%    0.030884  0.035976
# 75%    0.031272  0.037027
# max    0.031660  0.038078
#              cs       ncs  ncs-cs-fal
# count  3.000000  3.000000    3.000000
# mean   0.046917  0.043041    0.044383
# std    0.008314  0.013921    0.015841
# min    0.037451  0.027544    0.026440
# 25%    0.043858  0.037317    0.038357
# 50%    0.050264  0.047089    0.050274
# 75%    0.051650  0.050789    0.053354
# max    0.053036  0.054489    0.056435

# %%
display(df_group1.loc['T_50'])
display(df_group2.loc['T_50'])
# Out:
#            agg       fal
# T_50  0.044281  0.050486
# T_50  0.044632  0.049181
# T_50  0.049337  0.079916
#            cs       ncs  ncs-cs-fal
# T_50  0.11457  0.078394     0.12175
# T_50  0.13352  0.081888     0.11555
# T_50  0.12608  0.071733     0.10023

# %%
display(df_group1.loc['T_50'].describe())
display(df_group2.loc['T_50'].describe())
# Out:
#             agg       fal
# count  3.000000  3.000000
# mean   0.046083  0.059861
# std    0.002823  0.017380
# min    0.044281  0.049181
# 25%    0.044456  0.049834
# 50%    0.044632  0.050486
# 75%    0.046984  0.065201
# max    0.049337  0.079916
#              cs       ncs  ncs-cs-fal
# count  3.000000  3.000000    3.000000
# mean   0.124723  0.077338    0.112510
# std    0.009548  0.005159    0.011077
# min    0.114570  0.071733    0.100230
# 25%    0.120325  0.075064    0.107890
# 50%    0.126080  0.078394    0.115550
# 75%    0.129800  0.080141    0.118650
# max    0.133520  0.081888    0.121750

# %%
display(df_group1.loc['T_100'])
display(df_group2.loc['T_100'])
# Out:
#             agg       fal
# T_100  0.067287  0.097462
# T_100  0.049376  0.097546
# T_100  0.077915  0.141730
#             cs       ncs  ncs-cs-fal
# T_100  0.82890  0.142010     0.58338
# T_100  0.83871  0.086121     0.66066
# T_100  0.73507  0.159600     0.58303

# %%
display(df_group1.loc['T_100'].describe())
display(df_group2.loc['T_100'].describe())
# Out:
#             agg       fal
# count  3.000000  3.000000
# mean   0.064859  0.112246
# std    0.014424  0.025534
# min    0.049376  0.097462
# 25%    0.058332  0.097504
# 50%    0.067287  0.097546
# 75%    0.072601  0.119638
# max    0.077915  0.141730
#              cs       ncs  ncs-cs-fal
# count  3.000000  3.000000    3.000000
# mean   0.800893  0.129244    0.609023
# std    0.057215  0.038367    0.044719
# min    0.735070  0.086121    0.583030
# 25%    0.781985  0.114066    0.583205
# 50%    0.828900  0.142010    0.583380
# 75%    0.833805  0.150805    0.622020
# max    0.838710  0.159600    0.660660

# %%
display(df_group1.loc['T_200'])
display(df_group2.loc['T_200'])
# Out:
#             agg      fal
# T_200  0.081146  0.28814
# T_200  0.089451  0.34810
# T_200  0.082258  0.28230
#             cs      ncs  ncs-cs-fal
# T_200   6.0911  0.61283      3.6857
# T_200  10.4230  0.63705     13.7650
# T_200   6.4345  0.62127      3.7039

# %%
display(df_group1.loc['T_200'].describe())
display(df_group2.loc['T_200'].describe())
# Out:
#             agg       fal
# count  3.000000  3.000000
# mean   0.084285  0.306180
# std    0.004508  0.036421
# min    0.081146  0.282300
# 25%    0.081702  0.285220
# 50%    0.082258  0.288140
# 75%    0.085855  0.318120
# max    0.089451  0.348100
#               cs       ncs  ncs-cs-fal
# count   3.000000  3.000000    3.000000
# mean    7.649533  0.623717    7.051533
# std     2.408022  0.012294    5.814040
# min     6.091100  0.612830    3.685700
# 25%     6.262800  0.617050    3.694800
# 50%     6.434500  0.621270    3.703900
# 75%     8.428750  0.629160    8.734450
# max    10.423000  0.637050   13.765000
